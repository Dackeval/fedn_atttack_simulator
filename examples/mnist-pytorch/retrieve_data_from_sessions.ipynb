# %%
from fedn import APIClient

client_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzQ4Mjg4NjIzLCJpYXQiOjE3NDU2OTY2MjMsImp0aSI6ImQ5NjA1OTUzNmE4ZTQ4N2RhNjZiOWUzZmE2Yzk5Nzg3IiwidXNlcl9pZCI6MTYxLCJjcmVhdG9yIjoiU2NhbGVvdXRpbnRlcm4iLCJyb2xlIjoiYWRtaW4iLCJwcm9qZWN0X3NsdWciOiJtYXN0ZXJ0aGVzaXMteWFvIn0.UnmYLu6f8wv4T9A6ycTagIzqpdEwz_j-OsKubmL8cfo"

host = "api.fedn.scaleoutsystems.com/masterthesis-yao-fedn-reducer"

client = APIClient(host=f"{host}", token=f"{client_token}", secure=True, verify=True)

# %%
round_dict = client.get_rounds()
val_dict = client.get_validations()

# %%
model_trail
# Out:
# {'count': 31,
#  'result': [{'committed_at': 'Sat, 26 Apr 2025 19:38:56 GMT',
#    'model': 'f630c58d-abf5-4648-a008-1aae40fd4dbb',
#    'model_id': 'f630c58d-abf5-4648-a008-1aae40fd4dbb',
#    'name': None,
#    'parent_model': '14c85692-5001-42d5-88ca-ccc2d54718bd',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:31:40 GMT',
#    'model': 'e95b097b-ca4a-4178-b3d2-dec66a234f79',
#    'model_id': 'e95b097b-ca4a-4178-b3d2-dec66a234f79',
#    'name': None,
#    'parent_model': '05ae4147-a8f0-4904-9937-9b9b27e1beb1',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:33:14 GMT',
#    'model': 'e398494a-63bf-4558-84fa-3a5316254f6d',
#    'model_id': 'e398494a-63bf-4558-84fa-3a5316254f6d',
#    'name': None,
#    'parent_model': '22f72174-a0a5-4f91-a218-112632187709',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:37:52 GMT',
#    'model': 'c6af2d9d-1901-4ce7-b1c7-e61d9f72f2fc',
#    'model_id': 'c6af2d9d-1901-4ce7-b1c7-e61d9f72f2fc',
#    'name': None,
#    'parent_model': '951067c7-be75-4789-aa91-f80fe05ac197',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:32:18 GMT',
#    'model': 'c2cf6559-d6fd-4b71-a51c-bdf7c40eaba3',
#    'model_id': 'c2cf6559-d6fd-4b71-a51c-bdf7c40eaba3',
#    'name': None,
#    'parent_model': '0b304e2d-a524-465a-b8e6-25877bcecb67',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:37:14 GMT',
#    'model': 'b5fe8a1d-e7dc-4cf8-8a35-720fe373e9fa',
#    'model_id': 'b5fe8a1d-e7dc-4cf8-8a35-720fe373e9fa',
#    'name': None,
#    'parent_model': 'a8010388-b187-4d81-99b7-e41bb607c11e',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:36:50 GMT',
#    'model': 'a8010388-b187-4d81-99b7-e41bb607c11e',
#    'model_id': 'a8010388-b187-4d81-99b7-e41bb607c11e',
#    'name': None,
#    'parent_model': '4972c897-9ff8-4b6a-97ec-697aebcbc162',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:34:04 GMT',
#    'model': 'a5edddf4-963d-4a27-94ae-65a17503c215',
#    'model_id': 'a5edddf4-963d-4a27-94ae-65a17503c215',
#    'name': None,
#    'parent_model': '8b453463-aee6-4a62-b75e-ddcfd33648fc',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:35:31 GMT',
#    'model': 'a3409d0c-01f3-4943-9992-33279228ac65',
#    'model_id': 'a3409d0c-01f3-4943-9992-33279228ac65',
#    'name': None,
#    'parent_model': '1c81da9f-98da-4680-bf79-94202bb4749a',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:37:28 GMT',
#    'model': '951067c7-be75-4789-aa91-f80fe05ac197',
#    'model_id': '951067c7-be75-4789-aa91-f80fe05ac197',
#    'name': None,
#    'parent_model': 'b5fe8a1d-e7dc-4cf8-8a35-720fe373e9fa',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:29:56 GMT',
#    'model': '937cfe93-4ff3-4da3-bb66-02f51ed66e61',
#    'model_id': '937cfe93-4ff3-4da3-bb66-02f51ed66e61',
#    'name': None,
#    'parent_model': '4937a6a8-e541-4b1a-b328-fa4b93bcd196',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:33:42 GMT',
#    'model': '8b453463-aee6-4a62-b75e-ddcfd33648fc',
#    'model_id': '8b453463-aee6-4a62-b75e-ddcfd33648fc',
#    'name': None,
#    'parent_model': 'e398494a-63bf-4558-84fa-3a5316254f6d',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:39:16 GMT',
#    'model': '81e95a60-d1b6-4da2-921d-8e8482b1393b',
#    'model_id': '81e95a60-d1b6-4da2-921d-8e8482b1393b',
#    'name': None,
#    'parent_model': 'f630c58d-abf5-4648-a008-1aae40fd4dbb',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:34:51 GMT',
#    'model': '5a32038a-8207-44c8-817b-4f6b5a5e6849',
#    'model_id': '5a32038a-8207-44c8-817b-4f6b5a5e6849',
#    'name': None,
#    'parent_model': '3ca8d55d-9481-4f08-a099-5d9d60a54c8c',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:30:51 GMT',
#    'model': '57df7fef-e3a3-4f78-806a-16da2202315b',
#    'model_id': '57df7fef-e3a3-4f78-806a-16da2202315b',
#    'name': None,
#    'parent_model': '2955f180-6b51-434f-b3c5-49e42ac4147c',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:36:16 GMT',
#    'model': '4fcf99e1-788d-42c3-8bfe-a42afb40283e',
#    'model_id': '4fcf99e1-788d-42c3-8bfe-a42afb40283e',
#    'name': None,
#    'parent_model': '11789776-bf2f-43e3-b541-bc99e4d7254e',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:36:33 GMT',
#    'model': '4972c897-9ff8-4b6a-97ec-697aebcbc162',
#    'model_id': '4972c897-9ff8-4b6a-97ec-697aebcbc162',
#    'name': None,
#    'parent_model': '4fcf99e1-788d-42c3-8bfe-a42afb40283e',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:28:14 GMT',
#    'model': '4937a6a8-e541-4b1a-b328-fa4b93bcd196',
#    'model_id': '4937a6a8-e541-4b1a-b328-fa4b93bcd196',
#    'name': None,
#    'parent_model': None,
#    'session_id': None},
#   {'committed_at': 'Sat, 26 Apr 2025 19:30:18 GMT',
#    'model': '46d5f367-f0a2-429c-b5c1-d9a79c402fb8',
#    'model_id': '46d5f367-f0a2-429c-b5c1-d9a79c402fb8',
#    'name': None,
#    'parent_model': '937cfe93-4ff3-4da3-bb66-02f51ed66e61',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:34:30 GMT',
#    'model': '3ca8d55d-9481-4f08-a099-5d9d60a54c8c',
#    'model_id': '3ca8d55d-9481-4f08-a099-5d9d60a54c8c',
#    'name': None,
#    'parent_model': 'a5edddf4-963d-4a27-94ae-65a17503c215',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:31:20 GMT',
#    'model': '2a7e5863-fa8f-41ce-8772-ca7e77b03b5b',
#    'model_id': '2a7e5863-fa8f-41ce-8772-ca7e77b03b5b',
#    'name': None,
#    'parent_model': '57df7fef-e3a3-4f78-806a-16da2202315b',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:30:41 GMT',
#    'model': '2955f180-6b51-434f-b3c5-49e42ac4147c',
#    'model_id': '2955f180-6b51-434f-b3c5-49e42ac4147c',
#    'name': None,
#    'parent_model': '46d5f367-f0a2-429c-b5c1-d9a79c402fb8',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:32:52 GMT',
#    'model': '22f72174-a0a5-4f91-a218-112632187709',
#    'model_id': '22f72174-a0a5-4f91-a218-112632187709',
#    'name': None,
#    'parent_model': '1ef0462d-c1da-48eb-847b-1bcd3ce37706',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:32:36 GMT',
#    'model': '1ef0462d-c1da-48eb-847b-1bcd3ce37706',
#    'model_id': '1ef0462d-c1da-48eb-847b-1bcd3ce37706',
#    'name': None,
#    'parent_model': 'c2cf6559-d6fd-4b71-a51c-bdf7c40eaba3',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:35:16 GMT',
#    'model': '1c81da9f-98da-4680-bf79-94202bb4749a',
#    'model_id': '1c81da9f-98da-4680-bf79-94202bb4749a',
#    'name': None,
#    'parent_model': '5a32038a-8207-44c8-817b-4f6b5a5e6849',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:39:28 GMT',
#    'model': '1ad783d4-6a4b-4112-af2a-29b3416424e0',
#    'model_id': '1ad783d4-6a4b-4112-af2a-29b3416424e0',
#    'name': None,
#    'parent_model': '81e95a60-d1b6-4da2-921d-8e8482b1393b',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:38:28 GMT',
#    'model': '14c85692-5001-42d5-88ca-ccc2d54718bd',
#    'model_id': '14c85692-5001-42d5-88ca-ccc2d54718bd',
#    'name': None,
#    'parent_model': '08fa4328-bef7-484f-8497-c3f3fa6a9696',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:35:56 GMT',
#    'model': '11789776-bf2f-43e3-b541-bc99e4d7254e',
#    'model_id': '11789776-bf2f-43e3-b541-bc99e4d7254e',
#    'name': None,
#    'parent_model': 'a3409d0c-01f3-4943-9992-33279228ac65',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:31:59 GMT',
#    'model': '0b304e2d-a524-465a-b8e6-25877bcecb67',
#    'model_id': '0b304e2d-a524-465a-b8e6-25877bcecb67',
#    'name': None,
#    'parent_model': 'e95b097b-ca4a-4178-b3d2-dec66a234f79',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:38:17 GMT',
#    'model': '08fa4328-bef7-484f-8497-c3f3fa6a9696',
#    'model_id': '08fa4328-bef7-484f-8497-c3f3fa6a9696',
#    'name': None,
#    'parent_model': 'c6af2d9d-1901-4ce7-b1c7-e61d9f72f2fc',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'},
#   {'committed_at': 'Sat, 26 Apr 2025 19:31:30 GMT',
#    'model': '05ae4147-a8f0-4904-9937-9b9b27e1beb1',
#    'model_id': '05ae4147-a8f0-4904-9937-9b9b27e1beb1',
#    'name': None,
#    'parent_model': '2a7e5863-fa8f-41ce-8772-ca7e77b03b5b',
#    'session_id': '83f88eda-2922-4e36-83fa-4091204b2865'}]}

# %%
model_trail = client.get_models()
models = model_trail['result']
idx = 0
for model in models:
    idx += 1
    model_id = model['model_id']
    print(model_id)
    path = f"/Users/sigvard/Desktop/23:4:25 - Downloaded Sessions from Studio/{idx}_{model_id}.npz"
    client.download_model(model_id, path)
# Out:
# eeb3ef86-5e4e-47f0-a44b-64f336743846
# ec91637e-d56d-4807-bb1c-2695cf2edbe1
# e969af3c-9018-4d76-a2ee-89846053dcd2
# e379ae8f-bbfe-454e-bf83-ca2d384cd9b6
# e22c4ab8-f9d7-4f24-9b45-26c563460e4c
# c6649494-5ae7-4747-8006-945fae102e91
# c4e9e431-2fc8-48a8-8b32-0b97552edac6
# c17f2a80-8761-4d02-8370-b7274f28ae96
# ba3f6412-894b-4443-8e01-c57f4637a3be
# af67c3f6-fb3b-4922-9368-d0e211298099
# ae476b1a-0bdc-4c19-89af-698a39f9e7e2
# abd0c862-4216-4413-82f3-e9851c3a5f28
# a7f025d2-647a-4a9b-b896-7dd0341f0cf7
# 987cc09b-3dd2-48dd-82ef-55b3bb1afd8d
# 92d62fed-a1ab-4cdb-8857-a1e02ddfe906
# 78207266-10da-4ae8-b3d5-3dbb860913fe
# 75334d27-55bf-4296-af4a-a306b0cd2ade
# 624ec6f6-9179-4de5-9771-b495fb883017
# 61f1491d-5903-4aa5-a76e-819dc930f342
# 5bd34f20-f796-4371-94fe-69ca9030f98a
# 5a4ffe03-2473-49e9-8371-603a9e4995f8
# 5618347f-c035-4709-be3f-d2921743068a
# 5132cf3e-2979-4afa-9db5-a904cb2d4ce7
# 4ebb4c5b-99aa-4dc6-bb1b-5390e24d2dc3
# 467710b0-62f4-425c-bce2-72d5955bd041
# 21f72251-bf8f-4162-9737-c637339c6ffc
# 20918a2c-f4b4-4343-b1c3-9dd909d07e91
# 15016d16-85dd-40b1-ad87-d06c2e1c3805
# 0d2bb365-9b3b-424d-8c47-f13b30a35ae0
# 0a7a0517-830c-4bc8-b21f-8d476c21f1dd
# 02557d34-1ace-46bb-b835-173dfb4f1d70

# %%
import json 

path = "/Users/sigvard/Desktop/23:4:25 - Downloaded Sessions from Studio"

with open(f"{path}/round_dict.json", 'w') as f:
    json.dump(round_dict, f, indent=4)

with open(f"{path}/val_dict.json", 'w') as f:
    json.dump(val_dict, f, indent=4)
