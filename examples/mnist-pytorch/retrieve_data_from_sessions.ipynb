# %%
from fedn import APIClient

client_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzQ4Mjk3MDEzLCJpYXQiOjE3NDU3MDUwMTMsImp0aSI6IjNkOGY5ZWFlOGFmMjQ2ZTU4OThhMjhhMjU2ODY0NTJkIiwidXNlcl9pZCI6MTYxLCJjcmVhdG9yIjoiU2NhbGVvdXRpbnRlcm4iLCJyb2xlIjoiYWRtaW4iLCJwcm9qZWN0X3NsdWciOiJtdWx0aXNlc3Npb24tb3F1In0.yJxvHp0lN648uH6IgEGKYvq675TXEcpq65W4rxfZsrc"

host = "api.fedn.scaleoutsystems.com/multisession-oqu-fedn-reducer"

client = APIClient(host=f"{host}", token=f"{client_token}", secure=True, verify=True)

# %%
round_dict = client.get_rounds()
val_dict = client.get_validations()

# %%
model_trail
# Out:
# {'count': 31,
#  'result': [{'committed_at': 'Sat, 26 Apr 2025 20:15:36 GMT',
#    'model': 'fa959e5a-e079-4abf-a37d-7dee31528d86',
#    'model_id': 'fa959e5a-e079-4abf-a37d-7dee31528d86',
#    'name': None,
#    'parent_model': '3de0bf86-be9d-451b-a7d6-4750439c1224',
#    'session_id': '8238bc74-0497-4cf3-a8bf-195d2fc8879c'},
#   {'committed_at': 'Sat, 26 Apr 2025 20:15:02 GMT',
#    'model': 'f45258c5-163b-40b4-9f68-f185f118d840',
#    'model_id': 'f45258c5-163b-40b4-9f68-f185f118d840',
#    'name': None,
#    'parent_model': '4aa6c63c-1fbb-4818-9e40-d21b17fec915',
#    'session_id': '8238bc74-0497-4cf3-a8bf-195d2fc8879c'},
#   {'committed_at': 'Sat, 26 Apr 2025 20:08:30 GMT',
#    'model': 'e856ab3c-20d4-47e0-96b9-668ef2537c75',
#    'model_id': 'e856ab3c-20d4-47e0-96b9-668ef2537c75',
#    'name': None,
#    'parent_model': '33eef13f-0c31-47ef-be1e-a5d823ec06dd',
#    'session_id': '8238bc74-0497-4cf3-a8bf-195d2fc8879c'},
#   {'committed_at': 'Sat, 26 Apr 2025 20:12:24 GMT',
# ...

# %%
model_trail = client.get_models()
models = model_trail['result']
idx = 0
for model in models:
    idx += 1
    model_id = model['model_id']
    print(model_id)
    path = f"/Users/sigvard/Desktop/23:4:25 - Downloaded Sessions from Studio/{idx}_{model_id}.npz"
    client.download_model(model_id, path)
# Out:
# f2bd9423-621a-414c-9c23-c44a01f28b82
# f06d97ed-fc49-4d95-90cb-64a95680a036
# edf28cf3-f61f-4dc4-a024-af5e88d8fb92
# e63cf138-90b4-4ab6-bf2e-e13a2e0f3124
# ba286fd9-34a6-419c-8206-93776034b6aa
# b9cb6ce9-2d44-4d56-b2b3-a3610d830aa4
# b07d9c44-4f64-4e42-8d1a-b2930beb7a3b
# a6897fea-9df6-473f-9957-581009cbb4a7
# a35f615a-82d1-4a49-a15b-58d4afe0c2c9
# 94526ecd-bbbf-4b4c-b27b-62385974273a
# 815166e4-1e0d-4070-b804-c73951726ad1
# 7d1eadab-ea1a-4300-9e9e-28ea6f81806f
# 7c35c721-86ad-4ed8-b21e-731b7b5a257c
# 7a4c5353-b648-4410-9838-f9b5f3ced67b
# 7209cb7a-ec5d-4b2a-a9fc-a690e8d0a485
# 6546f39e-b97b-4e42-9cae-fa60dfe9bc0d
# 603411af-9433-46a9-8c4c-efddb6dc05dd
# 5baad790-6bb5-4f90-bc5b-59a154ff40a8
# 5848448f-e65e-4d3e-82a1-9dda85f0ed78
# 57121010-88c2-4b6c-9e13-25c417600155
# 5179180f-6a5b-44ee-b5a7-c3d07ec241ac
# 372b3d55-28d2-4bd1-9a58-f92ee59840df
# 2d85d1be-86a8-4f37-975e-09fffed9d717
# 2a759611-5e4e-492d-b732-ad88c6b78352
# 1ef8cfa3-be6f-4b9b-b63c-92c97b93eb95
# ...

# %%
import json 

path = "/Users/sigvard/Desktop/23:4:25 - Downloaded Sessions from Studio"

with open(f"{path}/round_dict.json", 'w') as f:
    json.dump(round_dict, f, indent=4)

with open(f"{path}/val_dict.json", 'w') as f:
    json.dump(val_dict, f, indent=4)
